# %% [markdown]
# <a href="https://colab.research.google.com/github/itsabbhii/Training-AIML/blob/main/RNN/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/itsabbhii/Training-AIML.git
# %cd Training-AIML/RNN
# Out:
# Cloning into 'Training-AIML'...
# remote: Enumerating objects: 262, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 262 (delta 22), reused 29 (delta 7), pack-reused 202 (from 1)
# Receiving objects: 100% (262/262), 33.12 MiB | 16.33 MiB/s, done.
# Resolving deltas: 100% (96/96), done.
# /content/Training-AIML/Training-AIML/RNN/Training-AIML/RNN/Training-AIML/RNN

# %%
from tensorflow.keras.layers import SimpleRNN, Input, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
from tensorflow.keras import Sequential
import tensorflow as tf

# %%
# Sample text data
data = [
    "I love programming",
    "Programming is fun",
    "Deep learning is powerful",
    "I love deep learning",
    "Artificial intelligence is the future",
    "Machine learning enables automation",
    "Coding improves problem-solving skills",
    "Python is a popular programming language",
    "Data science combines statistics and programming",
    "Learning to code is empowering",
    "Neural networks mimic the human brain",
    "Programming is both art and science",
    "Debugging code requires patience",
    "Algorithms drive technological innovation",
    "Big data fuels artificial intelligence",
    "I enjoy solving coding challenges",
    "Programming helps automate repetitive tasks",
    "I am passionate about technology",
    "Computer science is a fascinating field",
    "Cloud computing transforms how we work",
    "Software development requires creativity",
    "Artificial intelligence changes industries",
    "Learning programming languages is exciting",
    "Data visualization communicates insights",
    "AI models learn from data",
    "Machine learning can predict outcomes",
    "Understanding algorithms is essential",
    "Data engineering builds robust pipelines",
    "The internet connects the world",
    "Technology advances with research",
    "Learning from errors improves coding skills",
    "I aspire to become a great developer",
    "Automation simplifies everyday tasks",
    "AI assistants are becoming smarter",
    "Cybersecurity protects digital systems",
    "Programming helps solve real-world problems",
    "Technology is shaping the future",
    "Programming languages evolve over time",
    "Virtual reality creates immersive experiences",
    "Cloud storage makes data accessible",
    "Blockchain secures digital transactions",
    "Open-source software promotes collaboration",
    "API integration simplifies development",
    "Frontend development focuses on user interfaces",
    "Backend development powers applications",
    "Mobile app development is in demand",
    "Artificial intelligence learns from experience",
    "Natural language processing enables human-like communication",
    "Data analysis uncovers patterns in information",
    "The tech industry drives innovation",
    "Programming requires logical thinking",
    "I find joy in writing clean code",
    "Coding competitions sharpen skills",
    "Technology bridges geographical gaps",
    "AI ethics ensures responsible innovation",
    "Programming frameworks streamline development",
    "Robotics combines AI and engineering",
    "Learning data structures improves efficiency",
    "Programming bootcamps accelerate learning",
    "Collaboration enhances software development",
    "IoT connects devices to the internet",
    "Programming is a tool for problem-solving",
    "Understanding databases is key in data-driven fields",
    "AI chatbots improve customer service",
    "The future of programming is exciting",
    "Debugging is an art",
    "Learning from code reviews fosters growth",
    "Programming empowers creativity",
    "The demand for software engineers is growing",
    "AI in healthcare enhances diagnostics",
    "Data preprocessing is crucial in machine learning",
    "The journey of learning programming is rewarding",
    "Cloud computing enhances scalability",
    "AI makes personalized recommendations",
    "Learning to program is a lifelong journey",
    "Programming inspires innovation",
    "Machine learning models improve with feedback",
    "Understanding computer architecture is fundamental",
    "Data lakes store vast amounts of information",
    "I believe in the power of technology",
    "Coding simplifies complex processes",
    "AI in education personalizes learning experiences",
    "Programming nurtures problem-solving abilities",
    "I enjoy exploring new programming tools",
    "Artificial intelligence assists in creative tasks",
    "Programming courses are widely accessible online",
    "Data security ensures privacy",
    "Learning algorithms develops analytical thinking",
    "Programming is essential in the digital age",
    "AI transforms industries by automating tasks",
    "Cloud platforms provide flexible infrastructure",
    "Machine learning powers recommendation systems",
    "I am excited about the future of AI",
    "Debugging teaches attention to detail",
    "Programming projects develop practical skills",
    "The beauty of coding lies in its logic",
    "AI-driven automation boosts productivity",
    "Data scientists extract value from raw information",
    "Programming is a universal language",
    "Open-source projects build vibrant communities",
    "Machine learning unlocks hidden patterns",
    "Programming for AI requires mathematical skills",
    "Technology solves everyday challenges",
    "Programming is a creative outlet",
    "I believe programming changes lives",
    "Big data analytics informs decision-making",
    "AI mimics cognitive processes",
    "Programming involves constant learning",
    "Learning to code builds confidence",
    "AI in gaming creates realistic experiences",
    "The role of technology in society is profound",
    "Programming prepares us for future opportunities",
    "Cloud technologies improve collaboration",
    "Data-driven decisions are more effective",
    "AI improves accessibility for people with disabilities",
    "Programming transforms abstract ideas into reality",
    "Machine learning requires experimentation",
    "AI models are trained on diverse datasets",
    "Learning from failure is a programmer's strength",
    "Programming is a stepping stone to innovation",
    "The power of technology lies in its applications",
    "I find coding to be intellectually stimulating",
    "AI creates smarter solutions for complex problems",
    "Programming connects creativity with logic"
]

# %%
# Tokenising the data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
sequences = tokenizer.texts_to_sequences(data)

# %%
# Preparing input and output for RNN
vocab_size = len(tokenizer.word_index) + 1
input_sequences = []
for sequence in sequences:
    for i in range(1, len(sequence)):
        input_sequences.append(sequence[:i+1])

# %%
# pad sequence
max_len = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

# %%
# Split input x and target y
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# %%
model = Sequential([
    Embedding(vocab_size, 10, input_length=max_len-1),
    SimpleRNN(50, activation='tanh'),
    Dense(vocab_size, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X, y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.7444 - loss: 1.1952
# Epoch 2/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7399 - loss: 1.2613
# Epoch 3/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7692 - loss: 1.1200
# Epoch 4/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7797 - loss: 1.1400
# Epoch 5/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7570 - loss: 1.1662
# Epoch 6/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7747 - loss: 1.0817
# Epoch 7/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7442 - loss: 1.1097
# Epoch 8/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7868 - loss: 1.0821
# Epoch 9/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7936 - loss: 1.0136
# Epoch 10/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7589 - loss: 1.0653
# Epoch 11/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7656 - loss: 1.0592
# Epoch 12/200
# ...

# %%
# Testing the model
input_text = "I am"
tokenized_input = tokenizer.texts_to_sequences([input_text])[0]
tokenized_input = pad_sequences([tokenized_input], maxlen=max_len-1, padding='pre')

prediction = model.predict(tokenized_input)
predicted_index = tf.argmax(prediction, axis=-1).numpy()[0]
predicted_word = tokenizer.index_word[predicted_index]

print(f"Input Text: {input_text}")
print(f"Predicted Word: {predicted_word}")
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d6f5868eef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Input Text: I am
# Predicted Word: excited
